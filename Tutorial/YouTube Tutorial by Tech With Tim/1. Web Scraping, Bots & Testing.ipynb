# %%
from selenium import webdriver

path = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://techwithtim.net")
print(driver.title)
driver.quit()
# Out:
# <ipython-input-4-c807fd31f922>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# Tech With Tim - Python & Java Programming Tutorials - techwithtim.net
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://techwithtim.net")
print(driver.title)

bsObj = BeautifulSoup(driver.page_source)

tutorials =  bsObj.find('div',{"class":"menu-tutorials-container"}).findAll("li")

for tutorial in tutorials:
    print(tutorial.get_text())
# Out:
# <ipython-input-8-0c23ab13a7c4>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# Tech With Tim - Python & Java Programming Tutorials - techwithtim.net
# Interactive Lessons & Assessments
# Python Programming
# Game Development With Python
# Python Module Walk-Through’s
# Machine Learning With Python
# Python Neural Networks
# Django Tutorial
# Discord.py Tutorials
# Python AI Chat Bot Tutorial
# Voice Assistant Tutorial
# Flask Web Development
# Java Programming

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.techwithtim.net/")
bsObj = BeautifulSoup(html.read())

tutorials =  bsObj.find('div',{"class":"menu-tutorials-container"}).findAll("li")

for tutorial in tutorials:
    print(tutorial.get_text())
# Out:
# Interactive Lessons & Assessments
# Python Programming
# Game Development With Python
# Python Module Walk-Through’s
# Machine Learning With Python
# Python Neural Networks
# Django Tutorial
# Discord.py Tutorials
# Python AI Chat Bot Tutorial
# Voice Assistant Tutorial
# Flask Web Development
# Java Programming
