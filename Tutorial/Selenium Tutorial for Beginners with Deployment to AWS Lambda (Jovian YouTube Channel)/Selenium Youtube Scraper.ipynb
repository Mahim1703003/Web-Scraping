# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.youtube.com/feed/trending")
bsObj = BeautifulSoup(html.read(),'html.parser')

print(bsObj.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="bn-BD" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="AsKJ0YJfrprDHN9cO+Arkwlyt0SqGVbRekp6Ho6B0zL8/aWcEEa7mYjLrXVRY4E3+ZPTupaMmCxJOtl4ava9CgAAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2Njk3NjYzOTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/>
#   <script nonce="YVGRM3okMVCQ5luNzG25Qw">
#    var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20220921.00.00');
#   </script>
# ...

# %%
# it gives error cause it does not execute java script
print(bsObj.find("div",{"id":"text-container","class":"style-scope ytd-channel-name"}).get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-dd2573bff591> in <module>
#       1 # it gives error cause it does not execute java script
# ----> 2 print(bsObj.find("div",{"id":"text-container","class":"style-scope ytd-channel-name"}).get_text())
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
# same reason , it gives error cause it does not execute java script
video_divs = bsObj.findAll("div",{"id":"dismissible","class":"style-scope ytd-video-renderer"})
print(len(video_divs))
# Out:
# 0

# %%
# selenium installed
import selenium

# %%
from selenium import webdriver

path = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://www.youtube.com/feed/trending")

print("Page Title :",driver.title)
# Out:
# <ipython-input-5-d9dac987b380>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# Page Title : Trending - YouTube

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://www.youtube.com/feed/trending")

bsObj = BeautifulSoup(driver.page_source)

print(bsObj.findAll('ytd-video-renderer'))
# Out:
# <ipython-input-3-68d5e25b89f7>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# [<ytd-video-renderer bigger-thumbs-style="DEFAULT" class="style-scope ytd-expanded-shelf-contents-renderer" inline-title-icon="" lockup="true"><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=up6_3XS46RU" id="thumbnail" rel="null" tabindex="-1">
# <yt-image alt="" class="style-scope ytd-thumbnail" disable-upgrade="" ftl-eligible="" hidden="" notify-on-loaded="" notify-on-unloaded="">
# </yt-image>
# ...

# %%
# same code as previous one but won't execute

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.youtube.com/feed/trending")
bsObj = BeautifulSoup(html.read(),'html.parser')

print(bsObj.findAll('ytd-video-renderer'))
# Out:
# []

# %%
from selenium import webdriver

path = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://www.youtube.com/feed/trending")
print(driver.title)

driver.get("https://www.techwithtim.net")
print(driver.title)
# Out:
# <ipython-input-1-792a743237f7>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# Trending - YouTube
# Tech With Tim - Python & Java Programming Tutorials - techwithtim.net

# %%
from selenium import webdriver
import time

path = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://www.youtube.com/feed/trending")
print(driver.title)


time.sleep(5)

driver.get("https://www.techwithtim.net")
print(driver.title)

time.sleep(10)

driver.quit()
# Out:
# <ipython-input-5-57662c0027e8>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# Trending - YouTube
# Tech With Tim - Python & Java Programming Tutorials - techwithtim.net
